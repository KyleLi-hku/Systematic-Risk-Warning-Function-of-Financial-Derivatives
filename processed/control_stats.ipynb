# %%
import pandas as pd
df= pd.read_csv('(raw) Weekly_data.csv')
df.head()
# Out:
#    week  future_return     volume  inventory     amount    BASIS  \
# 0     1            NaN  10.976047   8.185907  10.976047  59.2680
# 1     2      -0.056701  13.400486  10.345831  13.400486  31.7160
# 2     3      -0.028819  13.474156  10.799555  13.474156  34.6024
# 3     4      -0.042739  13.527370  10.820138  13.527370  57.0780
# 4     5      -0.048364  14.049264  11.179381  14.049264  16.1712
#
#    index_turnover_rate  short_balance_ratio   pli  t_spread        RSI  \
# 0                0.440             0.000005  0.00   2.04740   0.000000
# 1                0.658             0.000010  0.20   2.01880  52.442353
# 2                0.490             0.000027  0.20   1.97462  18.350791
# 3                0.500             0.000028  0.25   1.94245  17.038370
# 4                0.468             0.000056  0.60   1.89940  48.441850
#
#    index_trading_volume  CCt+1
# 0              6.510794    0.0
# 1              8.499683    0.0
# 2              8.218636    0.0
# ...

# %%
df.drop(df.columns[[1,2,3,4,5]], axis=1, inplace=True)
df.head()
# Out:
#    week  index_turnover_rate  short_balance_ratio   pli  t_spread        RSI  \
# 0     1                0.440             0.000005  0.00   2.04740   0.000000
# 1     2                0.658             0.000010  0.20   2.01880  52.442353
# 2     3                0.490             0.000027  0.20   1.97462  18.350791
# 3     4                0.500             0.000028  0.25   1.94245  17.038370
# 4     5                0.468             0.000056  0.60   1.89940  48.441850
#
#    index_trading_volume  CCt+1
# 0              6.510794    0.0
# 1              8.499683    0.0
# 2              8.218636    0.0
# 3              7.993090    0.0
# 4              8.089973    0.0

# %%
df0 = df[df['CCt+1']==0]
df1 = df[df['CCt+1']==1]

# %%
df0
# Out:
#      week  index_turnover_rate  short_balance_ratio   pli  t_spread  \
# 0       1                0.440             0.000005  0.00   2.04740
# 1       2                0.658             0.000010  0.20   2.01880
# 2       3                0.490             0.000027  0.20   1.97462
# 3       4                0.500             0.000028  0.25   1.94245
# 4       5                0.468             0.000056  0.60   1.89940
# ..    ...                  ...                  ...   ...       ...
# 646   647                0.436             0.126962  0.60   0.73854
# 647   648                0.520             0.109330  0.60   0.79608
# 648   649                0.534             0.099007  0.80   0.73406
# 649   650                0.354             0.116676  0.40   0.70614
# 650   651                0.282             0.143002  0.40   0.67266
#
#            RSI  index_trading_volume  CCt+1
# 0     0.000000              6.510794    0.0
# 1    52.442353              8.499683    0.0
# ...

# %%
df1
# Out:
#      week  index_turnover_rate  short_balance_ratio       pli  t_spread  \
# 75     76               0.2540             0.002680  0.400000  0.253600
# 77     78               0.3020             0.002770  0.400000  0.517420
# 266   267               1.7420             0.004257  0.200000  1.831280
# 267   268               1.8300             0.003928  0.500000  1.775725
# 268   269               2.0460             0.002911  0.200000  1.749200
# 269   270               2.5120             0.002487  0.600000  1.507680
# 270   271               1.7560             0.002346  0.600000  1.187760
# 271   272               1.4900             0.002504  0.600000  1.131940
# 272   273               1.3020             0.002811  0.400000  1.208380
# 274   275               1.1800             0.002741  0.400000  1.303580
# 275   276               1.0920             0.003193  0.400000  1.264060
# 276   277               1.2000             0.003923  0.400000  1.201520
# ...

# %%
df0.mean(axis = 0, skipna = True)
# Out:
# week                    325.038462
# index_turnover_rate       0.499128
# short_balance_ratio       0.034402
# pli                       0.520459
# t_spread                  0.785972
# RSI                      51.689754
# index_trading_volume      8.658167
# CCt+1                     0.000000
# dtype: float64

# %%
df1.mean(axis = 0, skipna = True)
# Out:
# week                    348.222222
# index_turnover_rate       0.911463
# short_balance_ratio       0.018290
# pli                       0.439506
# t_spread                  0.934284
# RSI                      44.776015
# index_trading_volume      9.268927
# CCt+1                     1.000000
# dtype: float64
