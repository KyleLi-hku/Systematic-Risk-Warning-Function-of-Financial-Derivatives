# %%
#read balanced data
import pandas as pd
from sklearn import svm
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

df_rolling = pd.read_csv('balanced_df_weekly.csv')
df_rolling = df_rolling.dropna()
df_rolling = df_rolling.drop(['Unnamed: 0'], axis=1)
df_rolling.head()
# Out:
#    week  future_return     volume  inventory     amount    BASIS  \
# 0     2      -0.056701  13.400486  10.345831  13.400486  31.7160
# 1     3      -0.028819  13.474156  10.799555  13.474156  34.6024
# 2     4      -0.042739  13.527370  10.820138  13.527370  57.0780
# 3     5      -0.048364  14.049264  11.179381  14.049264  16.1712
# 4     6      -0.030835  14.229347  11.294284  14.229347  27.0700
#
#    index_turnover_rate  short_balance_ratio   pli  t_spread        RSI  \
# 0                0.658             0.000010  0.20   2.01880  52.442353
# 1                0.490             0.000027  0.20   1.97462  18.350791
# 2                0.500             0.000028  0.25   1.94245  17.038370
# 3                0.468             0.000056  0.60   1.89940  48.441850
# 4                0.448             0.000086  0.40   1.78708  42.878095
#
#    index_trading_volume  CCt+1
# 0              8.499683    0.0
# 1              8.218636    0.0
# 2              7.993090    0.0
# ...

# %%
from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits = 52)

# %%
train_splits, test_splits = tss.split(df_rolling)
train_split = train_splits[1]
test_split = test_splits[1]
print(train_split)
print(test_split)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25816\379482237.py in <module>
# ----> 1 train_splits, test_splits = tss.split(df_rolling)
#       2 train_split = train_splits[1]
#       3 test_split = test_splits[1]
#       4 print(train_split)
#       5 print(test_split)
#
# ValueError: too many values to unpack (expected 2)
